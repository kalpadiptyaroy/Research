# %% [markdown]
# # VGG - 16 Deep Learning Network Implementation in Pytorch.
#
# We are training the model on IEEE CovidChestXRay Dataset.

# %% [markdown]
# # Importing Libraries

# %%
# %matplotlib inline

import os
import shutil
import random
import torch
import torchvision
import numpy as np

from PIL import Image
from matplotlib import pyplot as plt
from IPython.display import clear_output

torch.manual_seed(0)
print('Using PyTorch Version', torch.__version__)
# Out:
# Using PyTorch Version 1.6.0+cpu

# %% [markdown]
# # Preparing Training and Test Sets

# %%
class_names = ['Covid', 'Non-Covid']
root_dir = 'Dataset'
source_dirs = ['Covid', 'Non-Covid']

if os.path.isdir(os.path.join(root_dir, source_dirs[1])):
    os.mkdir(os.path.join(root_dir, 'test'))

    for i, d in enumerate(source_dirs):
        os.rename(os.path.join(root_dir, d), os.path.join(root_dir, class_names[i]))

    for c in class_names:
        os.mkdir(os.path.join(root_dir, 'test', c))

    for c in class_names:
        images = [x for x in os.listdir(os.path.join(root_dir, c)) if (x[-3].lower().endswith('png') or x[-3:].lower().endswith('jpg') or x[-4:].lower().endswith('jpeg'))]
        selected_images = random.sample(images, 30)
        for image in selected_images:
            source_path = os.path.join(root_dir, c, image)
            target_path = os.path.join(root_dir, 'test', c, image)
            shutil.move(source_path, target_path)

# %% [markdown]
# # Creating Custom Dataset

# %%
class ChestXRayDataset(torch.utils.data.Dataset):
    def __init__(self, image_dirs, transform):
        def get_images(class_name):
            images = [x for x in os.listdir(image_dirs[class_name]) if (x[-3:].lower().endswith('png') or x[-3:].lower().endswith('jpg') or x[-4:].lower().endswith('jpeg')) ] 
            print(f'Found {len(images)} {class_name} examples')
            return images
        
        self.images = {}
        self.class_names = ['Covid', 'Non-Covid']
        
        for c in self.class_names:
            self.images[c] = get_images(c)
            
        self.image_dirs = image_dirs
        self.transform = transform
        
    def __len__(self):
        return sum([len(self.images[c]) for c in self.class_names])
    
    def __getitem__(self, index):
        class_name = random.choice(self.class_names)
        index = index % len(self.images[class_name])
        image_name = self.images[class_name][index]
        image_path = os.path.join(self.image_dirs[class_name], image_name)
        image = Image.open(image_path).convert('RGB')
        return self.transform(image), self.class_names.index(class_name)

# %% [markdown]
# # Image Transformations

# %%
train_transform = torchvision.transforms.Compose([
  torchvision.transforms.Resize(size=(224, 224)),
  torchvision.transforms.RandomHorizontalFlip(),
  torchvision.transforms.ToTensor(),
  torchvision.transforms.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.225, 0.224])  
])

test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(size=(224, 224)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean = [0.485, 0.456, 0.406],  std = [0.229, 0.225, 0.224]),
])

# %% [markdown]
# # Prepare DataLoader

# %%
train_dirs = {
    'Covid' : 'Dataset/Covid',
    'Non-Covid' : 'Dataset/Non-Covid'
}

train_dataset = ChestXRayDataset(train_dirs, train_transform)
# Out:
# Found 520 Covid examples
# Found 323 Non-Covid examples

# %%
test_dirs = {
    'Covid' : 'Dataset/test/Covid',
    'Non-Covid' : 'Dataset/test/Non-Covid'
}

test_dataset = ChestXRayDataset(test_dirs, test_transform)
# Out:
# Found 30 Covid examples
# Found 30 Non-Covid examples

# %%
batch_size = 6

dl_train = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle=True)
dl_test = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle=True)

print('Number of Training Batches', len(dl_train))
print('Number of Test Batches', len(dl_test))
# Out:
# Number of Training Batches 141
# Number of Test Batches 10

# %% [markdown]
# # Data Visualization

# %%
class_names = train_dataset.class_names

def show_images(images, labels, preds):
    plt.figure(figsize=(10, 4))
    for i, image in enumerate(images):
        plt.subplot(1, 6, i + 1, xticks=[], yticks=[])
        image = image.numpy().transpose((1, 2, 0))
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = image * std + mean
        image = np.clip(image, 0., 1.)
        plt.imshow(image)
        col = 'green' 
        if preds[i] != labels[i]:
            col = 'red'
        plt.xlabel(f'{class_names[int(labels[i].numpy())]}')
        plt.ylabel(f'{class_names[int(preds[i].numpy())]}', color=col)
    plt.tight_layout()
    plt.show()

# %%
images, labels = next(iter(dl_train))
show_images(images, labels, labels)

# %%
images, labels = next(iter(dl_test))
show_images(images, labels, labels)

# %% [markdown]
# # Creating the Model

# %%
vgg16 = torchvision.models.vgg16(pretrained=True)
print(vgg16)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
vgg16.classifier[6].out_features = 2

for params in vgg16.features.parameters():
    params.requires_grad = False

# %%
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(vgg16.classifier.parameters(), lr = 0.001, momentum=0.9)

# %%
def show_preds():
    vgg16.eval()
    images, labels = next(iter(dl_train))
    outputs = vgg16(images)
    _, preds = torch.max(outputs.data, 1)
    show_images(images, labels, preds)

# %%
show_preds
# Out:
# <function __main__.show_preds()>

# %% [markdown]
# # Define Train function

# %%
def train(epochs):
    print("Starting Training ...")
    accuracy_yaxis = []
    val_loss_yaxis = []
    steps_xaxis = []
    for e in range(0, epochs):
        print('_'*20)
        print(f'Starting epoch {e + 1} / {epochs}')
        print('_'*20)

        train_loss, val_loss = 0, 0
        vgg16.train()   # We set the vgg16 model to train mode

        for train_step, data in enumerate(dl_train):
            images, labels = data[0], data[1]
            optimizer.zero_grad()
            outputs = vgg16(images)
            loss = loss_fn(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            if train_step % 20 == 0:
                print('Evaluating at step', train_step)
                accuracy = 0
                vgg16.eval()

                for val_step, (images, labels) in enumerate(dl_test):
                    outputs = vgg16(images)
                    loss = loss_fn(outputs, labels)
                    val_loss += loss.item()
                    _, preds = torch.max(outputs.data, 1)
                    accuracy += sum((preds == labels).numpy())

                val_loss /= (val_step + 1)
                accuracy = accuracy / len(test_dataset)
                print(f'Validation Loss : {val_loss:.4f} Accuracy : {accuracy:.4f}')
                accuracy_yaxis.append(accuracy)
                val_loss_yaxis.append(val_loss)
                steps_xaxis.append(((len(dl_train) - 1) * e) + train_step)
                #show_preds()
                vgg16.train()

                if accuracy > 0.9:
                    print('Performance Condition Satisfied. Stopping ... ')
                    return

        train_loss /= (train_step + 1)
        print(f'Training Loss : {train_loss:.4f}')
    print('Training Complete ...')
    return (accuracy_yaxis, val_loss_yaxis, steps_xaxis)

# %%
# %%time
(accuracy_yaxis, val_loss_yaxis, steps_xaxis) = train(epochs = 10)
# Out:
# Starting Training ...
# ____________________
# Starting epoch 1 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.6865 Accuracy : 0.6500
# Evaluating at step 20
# Validation Loss : 1.4183 Accuracy : 0.5667
# Evaluating at step 40
# Validation Loss : 0.7957 Accuracy : 0.7000
# Evaluating at step 60
# Validation Loss : 0.6475 Accuracy : 0.7833
# Evaluating at step 80
# Validation Loss : 0.5945 Accuracy : 0.7333
# Evaluating at step 100
# Validation Loss : 0.7652 Accuracy : 0.7333
# Evaluating at step 120
# Validation Loss : 0.7016 Accuracy : 0.7167
# Evaluating at step 140
# Validation Loss : 0.8884 Accuracy : 0.7000
# Training Loss : 0.3161
# ____________________
# Starting epoch 2 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.7589 Accuracy : 0.6500
# Evaluating at step 20
# Validation Loss : 0.5847 Accuracy : 0.8333
# Evaluating at step 40
# Validation Loss : 0.6060 Accuracy : 0.7500
# Evaluating at step 60
# Validation Loss : 0.6818 Accuracy : 0.7167
# Evaluating at step 80
# Validation Loss : 0.9110 Accuracy : 0.6500
# Evaluating at step 100
# Validation Loss : 0.7214 Accuracy : 0.7833
# Evaluating at step 120
# Validation Loss : 0.9691 Accuracy : 0.6167
# Evaluating at step 140
# Validation Loss : 0.6848 Accuracy : 0.7000
# Training Loss : 0.3005
# ____________________
# Starting epoch 3 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.4126 Accuracy : 0.8000
# Evaluating at step 20
# Validation Loss : 0.5664 Accuracy : 0.8000
# Evaluating at step 40
# Validation Loss : 0.5078 Accuracy : 0.7500
# Evaluating at step 60
# Validation Loss : 0.7768 Accuracy : 0.7167
# Evaluating at step 80
# Validation Loss : 0.6233 Accuracy : 0.6500
# Evaluating at step 100
# Validation Loss : 0.4760 Accuracy : 0.8167
# Evaluating at step 120
# Validation Loss : 0.7888 Accuracy : 0.6667
# Evaluating at step 140
# Validation Loss : 0.8505 Accuracy : 0.7333
# Training Loss : 0.2045
# ____________________
# Starting epoch 4 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.6579 Accuracy : 0.7667
# Evaluating at step 20
# Validation Loss : 0.9486 Accuracy : 0.7167
# Evaluating at step 40
# Validation Loss : 0.7625 Accuracy : 0.7333
# Evaluating at step 60
# Validation Loss : 0.6219 Accuracy : 0.8000
# Evaluating at step 80
# Validation Loss : 0.7140 Accuracy : 0.7167
# Evaluating at step 100
# Validation Loss : 0.8784 Accuracy : 0.7167
# Evaluating at step 120
# Validation Loss : 0.8802 Accuracy : 0.7000
# Evaluating at step 140
# Validation Loss : 1.0364 Accuracy : 0.6833
# Training Loss : 0.2153
# ____________________
# Starting epoch 5 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.7261 Accuracy : 0.7167
# Evaluating at step 20
# Validation Loss : 0.9092 Accuracy : 0.7167
# Evaluating at step 40
# Validation Loss : 1.2970 Accuracy : 0.7167
# Evaluating at step 60
# Validation Loss : 0.9430 Accuracy : 0.7000
# Evaluating at step 80
# Validation Loss : 0.8067 Accuracy : 0.7667
# Evaluating at step 100
# Validation Loss : 0.9675 Accuracy : 0.7167
# Evaluating at step 120
# Validation Loss : 0.7641 Accuracy : 0.7667
# Evaluating at step 140
# Validation Loss : 1.3625 Accuracy : 0.5667
# Training Loss : 0.1526
# ____________________
# Starting epoch 6 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.8802 Accuracy : 0.7500
# Evaluating at step 20
# Validation Loss : 1.0793 Accuracy : 0.6500
# Evaluating at step 40
# Validation Loss : 0.9877 Accuracy : 0.6667
# Evaluating at step 60
# Validation Loss : 1.0437 Accuracy : 0.6667
# Evaluating at step 80
# Validation Loss : 1.0120 Accuracy : 0.7000
# Evaluating at step 100
# Validation Loss : 0.8723 Accuracy : 0.7667
# Evaluating at step 120
# Validation Loss : 0.7686 Accuracy : 0.7500
# Evaluating at step 140
# Validation Loss : 0.7521 Accuracy : 0.7333
# Training Loss : 0.2273
# ____________________
# Starting epoch 7 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.7802 Accuracy : 0.7333
# Evaluating at step 20
# Validation Loss : 0.7493 Accuracy : 0.8000
# Evaluating at step 40
# Validation Loss : 0.4947 Accuracy : 0.8167
# Evaluating at step 60
# Validation Loss : 0.7449 Accuracy : 0.7333
# Evaluating at step 80
# Validation Loss : 0.9597 Accuracy : 0.7167
# Evaluating at step 100
# Validation Loss : 0.7407 Accuracy : 0.7833
# Evaluating at step 120
# Validation Loss : 0.6924 Accuracy : 0.7333
# Evaluating at step 140
# Validation Loss : 0.6014 Accuracy : 0.8000
# Training Loss : 0.1341
# ____________________
# Starting epoch 8 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.6438 Accuracy : 0.7833
# Evaluating at step 20
# Validation Loss : 0.9913 Accuracy : 0.7000
# Evaluating at step 40
# Validation Loss : 0.8012 Accuracy : 0.8000
# Evaluating at step 60
# Validation Loss : 1.0288 Accuracy : 0.7667
# Evaluating at step 80
# Validation Loss : 0.9500 Accuracy : 0.7000
# Evaluating at step 100
# Validation Loss : 0.8431 Accuracy : 0.8000
# Evaluating at step 120
# Validation Loss : 0.7867 Accuracy : 0.7000
# Evaluating at step 140
# Validation Loss : 0.9104 Accuracy : 0.7667
# Training Loss : 0.1484
# ____________________
# Starting epoch 9 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.8262 Accuracy : 0.7500
# Evaluating at step 20
# Validation Loss : 0.7764 Accuracy : 0.7667
# Evaluating at step 40
# Validation Loss : 0.9435 Accuracy : 0.7500
# Evaluating at step 60
# Validation Loss : 1.6978 Accuracy : 0.6667
# Evaluating at step 80
# Validation Loss : 0.8246 Accuracy : 0.7167
# Evaluating at step 100
# Validation Loss : 0.6159 Accuracy : 0.7833
# Evaluating at step 120
# Validation Loss : 0.7341 Accuracy : 0.7333
# Evaluating at step 140
# Validation Loss : 0.8205 Accuracy : 0.7333
# Training Loss : 0.2040
# ____________________
# Starting epoch 10 / 10
# ____________________
# Evaluating at step 0
# Validation Loss : 0.5509 Accuracy : 0.8000
# Evaluating at step 20
# Validation Loss : 0.7549 Accuracy : 0.8000
# Evaluating at step 40
# Validation Loss : 1.1154 Accuracy : 0.7333
# Evaluating at step 60
# Validation Loss : 0.9773 Accuracy : 0.8000
# Evaluating at step 80
# Validation Loss : 0.8536 Accuracy : 0.7500
# Evaluating at step 100
# Validation Loss : 0.7949 Accuracy : 0.7667
# Evaluating at step 120
# Validation Loss : 0.9126 Accuracy : 0.6667
# Evaluating at step 140
# Validation Loss : 0.8087 Accuracy : 0.7167
# Training Loss : 0.1147
# Training Complete ...

# %% [markdown]
# # Final Results

# %%
show_preds()

# %% [markdown]
# # Plotting the Results

# %%
plt.plot(steps_xaxis, val_loss_yaxis, label = 'validation loss')
plt.plot(steps_xaxis, accuracy_yaxis, label = 'accuracy')
plt.legend()
plt.title('(Validation Loss , Accuracy) VS Train Step')
# Out:
# Text(0.5, 1.0, '(Validation Loss , Accuracy) VS Train Step')
